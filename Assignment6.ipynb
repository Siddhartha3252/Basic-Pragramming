# %%
1. Write a Python Program to Display Fibonacci Sequence Using Recursion?

# %%
#Answer :

def recurfib(n):
    if n<=1:
        return n
    else:
        return recurfib(n-1) + recurfib(n-2)

num = int(input("input no : "))

if num <=0:
    print("Please provide positive no.")

else:
    for i in range(num):
        print(recurfib(i) , end=" ")
# Out:
# input no : 7
# 0 1 1 2 3 5 8

# %%
2. Write a Python Program to Find Factorial of Number Using Recursion?

# %%
#Answer :

def fact(n):
    if n==0:
        return 1
    else:
        return n * fact(n-1)

num = int(input("input a no : "))

if num<0:
    print("Enter positive no.")
else:
    
        print(fact(num))
# Out:
# input a no : 7
# 5040

# %%
3. Write a Python Program to calculate your Body Mass Index?

# %%
#Answer :

h = float(input("enter your height in feet : "))
w = float(input("enter your weight in kilo : "))

bmi = w/(h**2)

print("The BIM is = ",bmi)
# Out:
# enter your height in feet : 70
# enter your weight in kilo : 70000
# The BIM is =  14.285714285714286

# %%
4. Write a Python Program to calculate the natural logarithm of any number?

# %%
#Answer :

import math
x = int(input(("Enter a number : ")))
log = math.log(x)
print("Log of {} is {}".format(x, log))
# Out:
# Enter a number : 7
# Log of 7 is 1.9459101490553132

# %%
5. Write a Python Program for cube sum of first n natural numbers?

# %%
#Answer :

num = int(input("Enter a no :"))
sum = 0
for i in range(1 , num+1):
    sum = sum + i**3
print("Cube sum of {} natural numbers is {}".format(num,sum))
# Out:
# Enter a no :7
# Cube sum of 7 natural numbers is 784
