# %%
1. Write a Python program to find sum of elements in list?

# %%
#Answer :

n = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)
print("Sum of elements in List",sum(lst))
# Out:
# Enter the lenth of your list : 5
# 2
# 3
# 4
# 6
# 7
# The List is  [2, 3, 4, 6, 7]
# Sum of elements in List 22

# %%
2. Write a Python program to Multiply all numbers in the list?

# %%
#Answer :

n = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)
product = 1
for i in lst:
    product = product*i
print("Product of elements in List is :",product)
# Out:
# Enter the lenth of your list : 5
# 4
# 3
# 4
# 3
# 4
# The List is  [4, 3, 4, 3, 4]
# Product of elements in List is : 576

# %%
3. Write a Python program to find smallest number in a list?

# %%
#Answer :

dn = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)
print("The Smallest no. in the list is :",min(lst))
# Out:
# Enter the lenth of your list : 5
# 4
# 34
# 3
# 4
# 3
# The List is  [4, 34, 3, 4, 3]
# The Smallest no. in the list is : 3

# %%
4. Write a Python program to find largest number in a list?

# %%
#Answer :

n = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)
print("The largest no. in the list is :",max(lst))
# Out:
# Enter the lenth of your list : 5
# 4
# 3
# 4
# 4
# 4
# The List is  [4, 3, 4, 4, 4]
# The largest no. in the list is : 4

# %%
5. Write a Python program to find second largest number in a list?

# %%
#Answer :

n = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)
lst.sort()
print("The sorted list is ",lst)
print("The second largest number in the list is ",lst[-2])
# Out:
# Enter the lenth of your list : 5
# 4
# 3
# 4
# 5
# 4
# The List is  [4, 3, 4, 5, 4]
# The sorted list is  [3, 4, 4, 4, 5]
# The second largest number in the list is  4

# %%
6. Write a Python program to find N largest elements from a list?

# %%
#Answer :

n = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)
lst.sort()
print("The sorted list is ",lst)
nlar = int(input("Enter how many largest number you want from list:"))

if n < nlar :
    print("enterted value is larger then the length of list")
else:
    print(nlar,"largest elements from the list are :",lst[(n-nlar):])
# Out:
# Enter the lenth of your list : 5
# 4
# 3
# 4
# 5
# 4
# The List is  [4, 3, 4, 5, 4]
# The sorted list is  [3, 4, 4, 4, 5]
# Enter how many largest number you want from list:5
# 5 largest elements from the list are : [3, 4, 4, 4, 5]

# %%
7. Write a Python program to print even numbers in a list?

# %%
#Answer :

lent =  int(input("Enter  the len of the list :"))
lst = []
for i in  range(lent):
  lst.append(int(input()))
print("The List is :" ,lst)
even = [i for i in lst if i%2==0 ]
print("The even numbers in list" , even)
# Out:
# Enter  the len of the list :5
# 4
# 3
# 4
# 3
# 4
# The List is : [4, 3, 4, 3, 4]
# The even numbers in list [4, 4, 4]

# %%
8. Write a Python program to print odd numbers in a List?

# %%
#Answer :


lent =  int(input("Enter  the len of the list :"))
lst = []
for i in  range(lent):
  lst.append(int(input()))
print("The List is :" ,lst)
odd = [i for i in lst if i%2 != 0 ]
print("The even numbers in list" , odd)
# Out:
# Enter  the len of the list :5
# 4
# 3
# 4
# 5
# 3
# The List is : [4, 3, 4, 5, 3]
# The even numbers in list [3, 5, 3]

# %%
9. Write a Python program to Remove empty List from List?

# %%
#Answer :


lst = [55,[],14,75,[],96,80,[],36]
print("The List :",lst)
new_list = [item for item in lst if item != []]
print("The list after removing empty lists :" , new_list)
# Out:
# The List : [55, [], 14, 75, [], 96, 80, [], 36]
# The list after removing empty lists : [55, 14, 75, 96, 80, 36]

# %%
10. Write a Python program to Cloning or Copying a list?

# %%
#Answer :


n = int(input("Enter the lenth of your list : "))
lst = []

for i in range(n):
    lst.append(int(input()))
print("The List is ",lst)

lst_copy = lst.copy()
print("Cloning By list copying lst ",lst_copy)
# Out:
# Enter the lenth of your list : 5
# 4
# 3
# 4
# 5
# 3
# The List is  [4, 3, 4, 5, 3]
# Cloning By list copying lst  [4, 3, 4, 5, 3]

# %% [markdown]
# 11. Write a Python program to Count occurrences of an element in a list?

# %%
#Answer :


lent = int(input("Enter the lenth of your list : "))
lst = []

for i in range(lent):
    lst.append(int(input()))
print("The List is ",lst)
ele= int(input("Enter the element to find its occurance : "))
print(ele,"has occured {} times in the list ".format(lst.count(ele)))
# Out:
# Enter the lenth of your list : 5
# 4
# 4
# 5
# 4
# 5
# The List is  [4, 4, 5, 4, 5]
# Enter the element to find its occurance : 5
# 5 has occured 2 times in the list
