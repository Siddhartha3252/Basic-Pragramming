# %%
1. Write a Python program to find words which are greater than given length k?

# %%
#Answer :

def Biggerthank(k,str):
    txt = str.split()
    Wordlist = []
    for i in txt:
        if len(i) > k:
            Wordlist.append(i)
    return Wordlist

str = input("Enter the string : ")
k = int(input("Enter the lenth K : "))

Wordlist = Biggerthank(k,str)

print("\nThe original string ' {} '".format(str))

print("Words greater than k{}".format(k))
print(Wordlist)
# Out:
# Enter the string : coding can change the life
# Enter the lenth K : 2
#
# The original string ' coding can change the life '
# Words greater than k2
# ['coding', 'can', 'change', 'the', 'life']

# %%
2. Write a Python program for removing i-th character from a string?

# %%
#Answer :

def remove(str, i): 
  
    for j in range(len(str)):
        if j == i:
            str = str.replace(str[i], "", 1)
    return str      

str = input("Enter the string : ")
i = int(input("Enter the index : "))      

# Print the new string

print("The new string : ", remove(str, i))
# Out:
# Enter the string : Siddhartha
# Enter the index : 3
# The new string :  Sidhartha

# %%
3. Write a Python program to split and join a string?

# %%
#Answer :

str = "Coding can change life"
str = str.split(" ") 
print("Spliting a string : ",str)


str2 = "-".join(str)
print("Joining a string : ",str2)
# Out:
# Spliting a string :  ['Coding', 'can', 'change', 'life']
# Joining a string :  Coding-can-change-life

# %%
4. Write a Python to check if a given string is binary string or not?

# %%
#Answer :

def ifbinary(str):
    binary = '01'
    for i in range(len(str)):
        if str[i] not in binary:
            print('Not Binary')
            break
    else:
        print('Binary')
        
str = input("Enter the string : ")
ifbinary(str)
# Out:
# Enter the string : 1011
# Binary

# %%
5. Write a Python program to find uncommon words from two Strings?

# %%
#Answer :

def unCommon(a,b):
    list_one = a.split()
    list_two = b.split()
    notcom =''
    
    for i in list_one:
        if i not in list_two:
            notcom = notcom +" "+ i
    for j in list_two:
        if j not in list_one:
            notcom = notcom +" "+ j
    return notcom

a = input("Enter the string a : ").lower()
b = input("Enter the string b : ").lower()

print("The list of un Common words : ", unCommon(a,b))
# Out:
# Enter the string a : siddhartha shrivastva
# Enter the string b : siddhartha loves coding shrivastva
# The list of un Common words :   loves coding

# %%
6. Write a Python to find all duplicate characters in string?

# %%
#Answer :

str = input("Enter the string a : ").lower()
duplicate = []

for i in str:
    if str.count(i) > 1 :
        if i not in duplicate:
            duplicate.append(i)
        
duplicate
# Out:
# Enter the string a : siddhartha
# ['d', 'h', 'a']

# %%
7. Write a Python Program to check if a string contains any special character?

# %%
#Answer :

import string

str_char = string.punctuation
speci_str = []

str = input("Enter the string a : ").lower()
for i in str:
    if i in str_char:
        speci_str.append(i)
if len(speci_str) > 0:
    print("String {} has special charecter/s : {}".format(str,speci_str))
# Out:
# Enter the string a : siddhartha@
# String siddhartha@ has special charecter/s : ['@']
